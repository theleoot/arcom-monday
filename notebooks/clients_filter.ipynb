# %%
# !pip install monday

# %% [markdown]
# # MODULES IMPORT

# %%
import pandas as pd

# %% [markdown]
# # LOAD DATAFRAME

# %%
df = pd.read_csv("U:/PowerBI/Geral/clientes_monitorados.csv", sep="/t", encoding="latin-1")

# %%
len(search.codRede.unique())
# Out:
# 24

# %%
search = df.query("tipoMonitoramento == 'Grande' and respCliente == 'ANDRESSA DOS SANTOS ALVES GOMES'")

# %%
search[search.codRede.isnull()]
# Out:
#      codCliente     cnpjCliente     fantasiaCliente  codRede fantasiaRede  \
# 16        44039  35817950000198           LOJA 1251      NaN          NaN
# 17        44787  41877520000164    FRANQUIA LJ 1260      NaN          NaN
# 18        45979  42018467000109       FRQ LOJA 1259      NaN          NaN
# 19        45980   7971786000133       FRQ LOJA 1261      NaN          NaN
# 25        51359  42563374000165    FRQ 267 UMUARAMA      NaN          NaN
# ..          ...             ...                 ...      ...          ...
# 273      924816  27798104000140  FRQ 240 INDAIATUBA      NaN          NaN
# 275      939295  24111291000153            LOJA 246      NaN          NaN
# 279      973408  35156359000137       FRQ 248 LAGES      NaN          NaN
# 283      980135  34335847000149    FRQ 240 SOROCABA      NaN          NaN
# 285      983884   8618554000169       PBKIDS LJ 115      NaN          NaN
#
#      dscRamoAtividade tipoMonitoramento estado       cidade latitudeCliente  \
# ...

# %%
len(df.query("tipoMonitoramento == 'Grande' and respCliente == 'ANDRESSA DOS SANTOS ALVES GOMES'")["codRede"].unique())
# Out:
# 24

# %%
df["tipoMonitoramento"].unique()
# Out:
# array(['Grande', 'Prospeccao'], dtype=object)

# %%
clientes_chave = df.query("clienteChave == 'S'")["codRede"].unique()

# %%
for cliente in clientes_chave:
    print(df.query(f"codRede == {cliente}").iloc[0][["codRede", "fantasiaCliente"]])
# Out:
# codRede               10756.0
# fantasiaCliente    DROGALIDER
# Name: 289, dtype: object
# codRede            52560.0
# fantasiaCliente     ARAUJO
# Name: 1258, dtype: object
# codRede                     509268.0
# fantasiaCliente    CENTRAL DE TROCAS
# Name: 3882, dtype: object
# codRede               579376.0
# fantasiaCliente    SANTA LUZIA
# Name: 6845, dtype: object
# codRede            612558.0
# fantasiaCliente    FRQ 1243
# Name: 7539, dtype: object
# codRede             622320.0
# fantasiaCliente    SUPERMAXI
# Name: 8082, dtype: object
# codRede               629309.0
# fantasiaCliente    ABC LOJA 51
# Name: 8167, dtype: object
# codRede                        718969.0
# fantasiaCliente    CDI - FARMACIA INDIA
# Name: 9687, dtype: object
# codRede                      865265.0
# fantasiaCliente    SAO JOAO FARMACIAS
# Name: 13892, dtype: object
# codRede                        887295.0
# fantasiaCliente    SUPERMERCADO BAHAMAS
# Name: 14608, dtype: object
# ...

# %%
"""
/*ASSOCIACOES MODIFICADAS RECENTEMENTE*/
SELECT
	DISTINCT
	ac.associacao,
	MAX(a.desc_associacao),
	MAX(ac.data_inicio)
FROM
	vendas.dbo.associacao_clientes ac
JOIN
	vendas.dbo.associacoes a
	on
	a.associacao = ac.associacao
GROUP BY 
	ac.associacao
HAVING
	MAX(ac.data_inicio) > '01-01-2025'
ORDER BY
	ac.associacao ASC;
"""

# %%
df.iloc[0]
# Out:
# codCliente                                  10951
# cnpjCliente                        25998204000194
# fantasiaCliente               TSUPERM. CRISTO REI
# codRede                                       NaN
# fantasiaRede                                  NaN
# dscRamoAtividade                     SUPERMERCADO
# tipoMonitoramento                          Grande
# estado                                         MG
# cidade                                 UBERLANDIA
# latitudeCliente                        -18,901866
# longitudeCliente                       -48,268167
# respCliente           GISLENE ANDRADE DE OLIVEIRA
# emailRespCli         gislene.andrade@arcom.com.br
# clienteChave                                    N
# Name: 0, dtype: object

# %%
df.fillna("")
# Out:
#      cliente tipo_monitoramento cliente_chave  usuario_responsavel  \
# 0      14361                  G             N               172650
# 1      20269                  G             S               172650
# 2      43320                  G             N               172650
# 3      43320                  G             N               172650
# 4      44038                  G             N               172650
# ..       ...                ...           ...                  ...
# 98    924816                  G             N               172650
# 99    939295                  G             N               172650
# 100   973408                  G             N               172650
# 101   980135                  G             N               172650
# 102   983884                  G             N               172650
#
#                                        razao_social      rede associacao  \
# 0                           DROGARIA ITAMARATY LTDA   14361.0
# ...

# %%
df = pd.read_csv("C:/Users/leonardo.tiago/OneDrive - Arcom SA/Área de Trabalho/PROJECTS/Monday Integration/CODE/DATA/_SELECT_TOP_1000_cvm_cliente_cvm_tipo_monitoramento_cvm_cliente__202504300928.csv")

df = df.fillna("")

clientes_andressa = df.to_numpy()

for x in clientes_andressa:
    cliente, tipo, cliente_chave, usuario, razao, rede, associacao, nome_associacao = x
    print(x)
# Out:
# [14361 'G' 'N' 172650 'DROGARIA ITAMARATY LTDA' 14361.0 '' '']
# [20269 'G' 'S' 172650 'IRMAOS MATTAR & CIA LTDA' 718969.0 '' '']
# [43320 'G' 'N' 172650 ' ITAITUBA KIDS COMERCIO DE BRINQUEDOS EIRELI'
#  15136.0 29.0 'RI HAPPY / PBKIDS']
# [43320 'G' 'N' 172650 ' ITAITUBA KIDS COMERCIO DE BRINQUEDOS EIRELI'
#  15136.0 29.0 'RI HAPPY / PBKIDS']
# [44038 'G' 'N' 172650 'MAGALHAES COMERCIO DE BRINQUEDOS LTDA.' 521852.0
#  29.0 'RI HAPPY / PBKIDS']
# [44039 'G' 'N' 172650
#  'CL BRINQUEDOS E ARTIGOS RECREATIVOS E INFANTIS   LTDA' '' 29.0
#  'RI HAPPY / PBKIDS']
# [44787 'G' 'N' 172650 'MANA BRINQUEDOS LTDA' '' 29.0 'RI HAPPY / PBKIDS']
# [45979 'G' 'N' 172650 'A DE M B GORGEN LTDA' '' 29.0 'RI HAPPY / PBKIDS']
# [45980 'G' 'N' 172650 'MARIA DO SOCORRO ROCHA DE MEDEIROS GUEDES' '' 29.0
#  'RI HAPPY / PBKIDS']
# [47168 'G' 'N' 172650 'LACERDA COMERCIO LTDA' 47168.0 29.0
#  'RI HAPPY / PBKIDS']
# [51359 'G' 'N' 172650 'UMUARAMA BRINQUEDOS LTDA' '' 29.0
#  'RI HAPPY / PBKIDS']
# ...

# %%
some = " "

"S" if some else "N"
# Out:
# 'S'

# %%
from dataclasses import dataclass

import pandas as pd
from monday import MondayClient


@dataclass
class MondayDashboardData:
    def __init__(self, token: str):
        self.token: str = token
        self.client: MondayClient = MondayClient(token)
    
    @property
    def items(self):
        return self.client.items
    
    @property
    def boards(self):
        return self.client.boards
    
    @property
    def get(self):
        dashboard_search = self.items.fetch_items_by_column_value(
            board_id="8895172235", 
            column_id="numeric_mkqfj2fw",
            value="",
            limit=500
        )

        return dashboard_search

    @property
    def me(self):
        return self.client.me.get_details()
        
    def get_board(self, board_id: str):
        board_search = self.boards.fetch_items_by_board_id(board_id)
        return board_search

clients_board = MondayDashboardData("eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjUwNjA5ODU5OSwiYWFpIjoxMSwidWlkIjo3NDU0NDU5OSwiaWFkIjoiMjAyNS0wNC0yOVQxNDowMjoxOS4wMDBaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6Mjg5NzM1NjYsInJnbiI6InVzZTEifQ.0k3DE8V2o5grKALDpyGNiqBmLqA8N3fnsBma_WYpkjM")

board_data = clients_board.get_board("8895172235")

# %%
{
    "company": {
        "name": "Some", 
        "id": "1156165"
    }
}
# Out:
# {'company': {'name': 'Some', 'id': '1156165'}}

# %%
board_data["data"]["boards"][0]["items_page"]["items"][0]
# Out:
# {'group': {'id': 'topics', 'title': 'Empresas'},
#  'id': '8895177362',
#  'name': 'Drugstore Araujo S/A',
#  'column_values': [{'id': 'subtasks_mkppzgcs',
#    'text': None,
#    'type': 'subtasks',
#    'value': '{}'},
#   {'id': 'multiple_person_mkpp7q97',
#    'text': 'Leonardo',
#    'type': 'people',
#    'value': '{"changed_at":"2025-04-04T17:13:44.278Z","personsAndTeams":[{"id":74544948,"kind":"person"}]}'},
#   {'id': 'account_contact',
#    'text': None,
#    'type': 'board_relation',
#    'value': '{}'},
#   {'id': 'account_deal', 'text': None, 'type': 'mirror', 'value': None},
#   {'id': 'industry',
#    'text': 'Saúde, Bens de consumo',
#    'type': 'dropdown',
#    'value': '{"ids":[60,54],"changed_at":"2025-04-04T16:41:28.805Z","override_all_ids":"true"}'},
#   {'id': 'company_description',
#    'text': '',
#    'type': 'long_text',
#    'value': None},
#   {'id': 'employee_count', 'text': '200', 'type': 'text', 'value': '"200"'},
# ...

# %% [markdown]
# # PROPOSTAS

# %%
import json
import pandas as pd
from typing import Dict, Any

from monday import MondayClient


class MondayDashboardHandler:
    """
    A class to handle interactions with Monday.com dashboard.

    This class provides functionality to create and manage items in a Monday.com board,
    particularly focused on managing company and contact information.

    Parameters
    ----------
    api_key : str
        The API key for authenticating with Monday.com.

    Attributes
    ----------
    client : monday.MondayClient
        The Monday.com client instance.
    board_id : str
        The ID of the target Monday.com board.
    group_id : str
        The ID of the group where items will be created.
    """

    def __init__(self, board_id: str, group_id: str, api_key: str):
        """
        Initialize the Monday client with the provided API key.

        Parameters
        ----------
        api_key : str
            The API key for Monday.com.
        """
        self.board_id = board_id or "8895172812"
        self.group_id = group_id or "topics"
        self.client = MondayClient(api_key)

    def create_item(self, item_name: str, **fields) -> Dict[str, Any]:
        """
        Create a new item in the Monday dashboard with the specified data.

        Parameters
        ----------
        item_name : str
            Name of the item to be created.
        **fields : dict
            Additional column values for the item.

        Returns
        -------
        Dict[str, Any]
            Response from the Monday API.

        Raises
        ------
        RuntimeError
            If item creation fails.
        """
        try:
            response = self.client.items.create_item(
                board_id=self.board_id,
                item_name=item_name,
                column_values=fields,
                group_id=self.group_id,
            )
            return response
        except Exception as e:
            raise RuntimeError(f"Failed to create item in Monday dashboard: {str(e)}")

# %%
dataset
# Out:
# array([[42791, 622320, 'INTRODUÃ├O STARLUX ENERGY', 'E',
#         '2025-01-02 10:04:00.000', 172650, 1.0,
#         'SUPER MAXI SUPERMERCADOS LTDA'],
#        [42811, 536098, 'VOLTA AS AULAS', 'E', '2025-01-08 21:07:00.000',
#         172650, 10302.36, 'DVILLE SUPERMERCADOS S.A.'],
#        [42875, 162453, 'INTRODUCAO MARCAS PARA NEGOCIAÃ├O MOTO', 'E',
#         '2025-01-13 16:03:00.000', 151662, 10082.74,
#         'PONTO ALTO SUPERMERCADO LTDA'],
#        [42903, 10756, 'JBP 2025', 'E', '2025-01-16 21:29:00.000', 172650,
#         1.0, 'LIDER ORGANIZACAO COMERCIAL LTDA'],
#        [42921, 806326, 'INTRODUÃ├O STARLUX ENERGY', 'E',
#         '2025-01-20 17:16:00.000', 154815, 126241.4,
#         'SUPERMERCADOS BH COMERCIO DE ALIMENTOS S/A'],
#        [42939, 997986, 'CARLOS VAZ PROPOSTA COTY E TRIM', 'E',
#         '2025-01-23 10:12:00.000', 166082, 0.1,
#         'PERFUMARIA PRINCESA DOESTE LTDA'],
#        [42990, 887295, 'REATIVAÃ├O SLIMES - 887295', 'E',
# ...

# %%
    # INSERT "NOGOCIAÇÕES" DATA
    api_key = "eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjUwNjA5ODU5OSwiYWFpIjoxMSwidWlkIjo3NDU0NDU5OSwiaWFkIjoiMjAyNS0wNC0yOVQxNDowMjoxOS4wMDBaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6Mjg5NzM1NjYsInJnbiI6InVzZTEifQ.0k3DE8V2o5grKALDpyGNiqBmLqA8N3fnsBma_WYpkjM"
    monday_handler = MondayDashboardHandler(board_id="8895172812", group_id="group_mkppsanx", api_key=api_key)

    # Create a sample item
    try:
        df = pd.read_csv("C:/Users/leonardo.tiago/OneDrive - Arcom SA/Área de Trabalho/PROJECTS/Monday Integration/CODE/DATA/_PROPOSTAS_SELECT_pvm_id_proposta_vda_monitorada_pvm_cliente_pvm_202504301656.csv")

        df = df.query("situacao_proposta == 'R'")
        
        df = df.fillna("")

        dataset = df.to_numpy()

        user_list = {
            "172650": "74628342"
        }

        user = lambda x: user_list[x] if x in user_list else None 
        
        for x in dataset:
            proposta, cliente, descricao, situacao, data, usuario, valor, razao = x

            data = str(pd.to_datetime(data).date())

            # check_associacao = "S" if associacao else "N"

            response = monday_handler.create_item(
                item_name=razao,
                deal_owner=user(str(usuario)),
                deal_value=str(valor),
                text_mkqg2wss=descricao,
                numeric_mkqgayeh=cliente,
                numeric_mkqg92e2=proposta,
                date_mkqgk1rw=data
            )
        print("Items created successfully!")
    except RuntimeError as e:
        print(e)
# Out:
# Items created successfully!

# %%
example = "some"
f"{example}"
# Out:
# 'some'

# %%
# TEST API RETURN PARAMETERS

promotores = MondayDashboardHandler(board_id="8895173426", group_id="topics", api_key=api_key)

item_info = promotores.create_item(
    item_name="Test",
    numeric_mkqeqgqd="1"
)
# Out:
# {'data': {'create_item': {'id': '9055165999'}}, 'account_id': 28973566}

# %%
# READ Sql TEST

# %%
import sqlite3
con = sqlite3.connect("C:/Users/leonardo.tiago/OneDrive - Arcom SA/PROGRAMS/AI SERVER/database/sample.db")

movies = pd.read_sql("SELECT * FROM movie;", con)

# %%
data = pd.DataFrame([{"title": "Test Movie", "year": 2024, "score": 8}])

# %%
movies = pd.concat([movies, data]).reset_index(drop=True)

# %%
data.to_sql(name="movie", con=con, if_exists="replace")
# Out:
# 1

# %%
# BOARD DATA

# %%
from dataclasses import dataclass

import pandas as pd
from monday import MondayClient


@dataclass
class MondayDashboardData:
    def __init__(self, token: str):
        self.token: str = token
        self.client: MondayClient = MondayClient(token)
    
    @property
    def items(self):
        return self.client.items
    
    @property
    def boards(self):
        return self.client.boards

    def normalize_data(self, data):
        return data["data"]["boards"][0]
    
    def get_board(self, board_id: str):
        board_search = self.boards.fetch_items_by_board_id(board_id)
        return self.normalize_data(board_search)

clients_board = MondayDashboardData("eyJhbGciOiJIUzI1NiJ9.eyJ0aWQiOjUwNjA5ODU5OSwiYWFpIjoxMSwidWlkIjo3NDU0NDU5OSwiaWFkIjoiMjAyNS0wNC0yOVQxNDowMjoxOS4wMDBaIiwicGVyIjoibWU6d3JpdGUiLCJhY3RpZCI6Mjg5NzM1NjYsInJnbiI6InVzZTEifQ.0k3DE8V2o5grKALDpyGNiqBmLqA8N3fnsBma_WYpkjM")

board_data = clients_board.get_board("8895173426")
print(board_data)
# Out:
# {'name': 'Promotores', 'items_page': {'cursor': None, 'items': [{'group': {'id': 'topics', 'title': 'Promotores de Vendas'}, 'id': '8895178029', 'name': 'Farmácia Indiana', 'column_values': [{'id': 'subtasks_mkpn3s6m', 'text': None, 'type': 'subtasks', 'value': '{"linkedPulseIds":[{"linkedPulseId":8895178609}]}'}, {'id': 'people', 'text': 'ANDRESSA DOS SANTOS ALVES GOMES', 'type': 'people', 'value': '{"changed_at":"2025-04-28T12:25:53.141Z","personsAndTeams":[{"id":74628342,"kind":"person"}]}'}, {'id': 'dropdown_mkpng3yv', 'text': None, 'type': 'dropdown', 'value': '{"ids":[]}'}, {'id': 'status_1', 'text': 'Não Acompanhado', 'type': 'status', 'value': '{"index":2,"post_id":null,"changed_at":"2022-05-19T11:41:33.138Z"}'}, {'id': 'files', 'text': 'https://arcom6.monday.com/docs/8895178400, https://arcom6.monday.com/protected_static/28973566/resources/2071162573/REC.csv', 'type': 'file', 'value': '{"files":[{"name":"monday Doc","fileId":"c03bc251-fab8-4041-8640-e12d216a1869","isImage":"
# ...

# %%
board_data["items_page"]["items"][1]
# Out:
# {'group': {'id': 'topics', 'title': 'Promotores de Vendas'},
#  'id': '8895177990',
#  'name': 'Supermercado BH',
#  'column_values': [{'id': 'subtasks_mkpn3s6m',
#    'text': None,
#    'type': 'subtasks',
#    'value': '{}'},
#   {'id': 'people',
#    'text': 'ANDRESSA DOS SANTOS ALVES GOMES',
#    'type': 'people',
#    'value': '{"changed_at":"2025-04-28T12:25:51.272Z","personsAndTeams":[{"id":74628342,"kind":"person"}]}'},
#   {'id': 'dropdown_mkpng3yv',
#    'text': 'BH - 01',
#    'type': 'dropdown',
#    'value': '{"ids":[8]}'},
#   {'id': 'status_1',
#    'text': 'Não Acompanhado',
#    'type': 'status',
#    'value': '{"index":2,"post_id":null,"changed_at":"2025-04-03T19:28:45.166Z"}'},
#   {'id': 'files', 'text': '', 'type': 'file', 'value': None},
#   {'id': 'numeric_mkqeqgqd', 'text': '', 'type': 'numbers', 'value': None}]}

# %%
columns_map = {
    "subtasks_mkpn3s6m": 
}

for board_element in board_data["items_page"]["items"]:
    for columns data in board_element["column_values"]:
        pass

    print(
        {
            "element_id": board_element["id"],
            "company_name": board_element["name"],
            # "company_name": board_element.,
        }
    )
# Out:
#   Cell In[301], line 2
#     "subtasks_mkpn3s6m":
#                        ^
# SyntaxError: expression expected after dictionary key and ':'
